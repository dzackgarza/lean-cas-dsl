# %% [markdown]
# # CasDsl — the refusal catalogue
#
# Every refusal in CasDsl is a sentence: it names the operation, the
# object, and the reason. This notebook demonstrates them live — each
# output below is the genuine kernel refusal — so that
# [demo.ipynb](demo.ipynb) can stay a runnable trail.
#
# A caveat for interactive use: the document model refuses to build
# on a failed cell, so running top-down stops at the first refusal —
# the stop is itself the design. To exercise a later refusal live,
# comment out the refusal cells above it (`--` begins a comment,
# exactly as in Lean) and re-run.

# %% [markdown]
# ## Reserved constants
#
# `e` and `i` are never shadowable — `e^t` and `2 + 2i` mean the same
# thing in every session state, so a rebinding refuses:

# %%
let e := 5 in ℤ
# Out:
# Starting Lean worker (/home/dzack/gitclones/lean-cas-dsl)…
# `e` is reserved for Euler's constant (`e^t` = exp(t)) and cannot be rebound

# %%
let i := 3 in ℤ
# Out:
# `i` is reserved for the imaginary unit i ∈ ℂ, so it cannot be rebound

# %% [markdown]
# ## Cross-category equality
#
# `F` is a module and `{0, 1, 2, 3}` a set: bare `=` never inserts
# the forgetful functor, so the equality is false. The Sets question
# is `set_eq`, receiver transported — and it answers:

# %%
let F := ℤ/4 in Modules(ℤ)
# Out:
# F := ℤ/4 as ℤ-module

# %%
assert F = {0, 1, 2, 3}
# Out:
# assertion is false: F = {0, 1, 2, 3}

# %%
F.set_eq({0, 1, 2, 3})
# Out:
# true

# %% [markdown]
# ## Symbolic bodies are never evaluated at a point
#
# A body the polynomial engine cannot express is symbolic: the
# expression is presented for a limit, a definite integral or a
# Taylor expansion, and evaluation at a point is not implemented:

# %%
let sine: ℝ → ℝ := t ↦ sin(t)
let recip := t ↦ 1/t in ℝ → ℝ
# Out:
# sine := t ↦ sin(t) ∈ ℝ → ℝ
# recip := t ↦ 1/t ∈ ℝ → ℝ

# %%
sine(0)
# Out:
# t ↦ sin(t) has a symbolic body: the expression is presented for a limit, a definite integral or a Taylor expansion, and evaluation at a point is not implemented for symbolic bodies

# %%
recip(2)
# Out:
# t ↦ 1/t has a symbolic body: the expression is presented for a limit, a definite integral or a Taylor expansion, and evaluation at a point is not implemented for symbolic bodies

# %% [markdown]
# ## A function needs its domain and codomain
#
# A bare `↦` has no ascription to check against:

# %%
let bad := t ↦ t^2
# Out:
# `t ↦ …` needs an ascription naming its domain and codomain, as in `let h := t ↦ t^2 + 1 in ℝ → ℝ`

# %% [markdown]
# ## Domains must compose, and arguments must belong

# %%
let h := t ↦ t² + 1 in ℝ → ℝ
let m2: ℕ → ℕ := n ↦ 2n
# Out:
# h := t ↦ t^2 + 1 ∈ ℝ → ℝ
# m2 := n ↦ 2n ∈ ℕ → ℕ

# %%
assert (h ∘ m2)(t) = t
# Out:
# ℕ → ℕ and ℝ → ℝ do not compose: the target of the right factor is not the source of the left

# %%
m2(-1)
# Out:
# -1 is not an element of ℕ

# %% [markdown]
# ## A morphism is not an object
#
# Ascribing a hom to `Mod(ℚ)` states membership among the category's
# objects — and a map is not one:

# %%
let gm: QQ^3 -> QQ := (a, b, c) |-> a + b - c in Mod(QQ)
# Out:
# a hom is a morphism, not an object of Mod(ℚ); ascribing it there is refused rather than read as membership — the arrow `(a, b, c) ↦ a + b - c ∈ ℚ³ → ℚ` already names its domain and codomain

# %% [markdown]
# ## Reserved spellings
#
# Spellings SPEC.md fixes for features not implemented yet still
# parse, and refuse by name — never as syntax errors:

# %%
let Rf := CC[x_0, x_1, ..., x_9]
# Out:
# D[x_0, x_1, ..., x_n] — a polynomial algebra on a family of indeterminates (SPEC.md §Ellipses) — is not implemented: the spelling is reserved for it. One indeterminate — `ℂ[x]` — is available

# %%
AA^2(QQ)
# Out:
# AA^n(K) — affine n-space over K — is not implemented: the spelling is reserved for it

# %% [markdown]
# ## `E[[t]]/(t^k)` is a truncation request, not a ring here
#
# It occurs only as the target of `map … to`; membership in it is not
# a question this system answers:

# %%
let sq(t) = ∑_{n ∈ ℕ} n^2 t^n ∈ ℤ[[t]]
# Out:
# sq := t + 4t^2 + 9t^3 + 16t^4 + ... ∈ ℤ[[t]]

# %%
assert sq ∈ ℤ[[t]]/(t^5)
# Out:
# `E[[t]]/(t^5)` occurs here only as the target of `map … to` — a request that a series be presented by its first 5 coefficients. The quotient ring itself is not presented in CasDsl, so it answers no membership, cardinality or inclusion question

# %% [markdown]
# ## NoImplementation — availability without an implementation
#
# `det` is declared on Mat₂(ℤ/5); no route executes it there yet. The
# refusal is a structured gap, never a narrowing of the mathematics:

# %%
let N := [1, 2; 3, 4] in Mat₂(ℤ/5)
# Out:
# N := [1, 2; 3, 4] ∈ Mat₂(ℤ/5)

# %%
N.det()
# Out:
# NoImplementation: 'det' is mathematically available for x = [1, 2; 3, 4] ∈ Mat₂(ℤ/5) (declared directly on MatrixElems(2, ℤ/5)), but the registered routes — element of Mat(_, ℚ) → sage "mat_det_q" — accept none of it.
# The method stays available on MatrixElems(2, ℤ/5); the mathematics is not narrowed — an implementation for this presentation does not exist yet.
